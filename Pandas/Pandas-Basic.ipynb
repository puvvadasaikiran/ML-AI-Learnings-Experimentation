# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #What is Difference between Series and DataFrame
#
# > Series is a one dimensional ndarray
#
# > DataFrame is two dimensional ndarray
#
# > Each individual Column in a Dataframe is a Series, when we put n series together its Dataframe where n>=2

# %%
pets = ['Lion', 'Cat', 'Birds','Fish','Rat']
pd.Series(pets)
# Out:
# 0     Lion
# 1      Cat
# 2    Birds
# 3     Fish
# 4      Rat
# dtype: object

# %%
pets = [['A1','A2','A3','A4','A5'],['Lion', 'Cat', 'Birds','Fish','Rat']]
pd.DataFrame(pets[1:],columns=pets[0])
# Out:
#      A1   A2     A3    A4   A5
# 0  Lion  Cat  Birds  Fish  Rat

# %% [markdown]
# ## We can override the default index in series

# %%
my_days=['Monday','Tuesday','Wednesday','Thursday','Friday']
my_courses=['Economics','Geograghy','Finance','Mathematics','History']
seriesWithRiggedIndex= pd.Series(my_courses,index=my_days)
seriesWithRiggedIndex
# Out:
# Monday         Economics
# Tuesday        Geograghy
# Wednesday        Finance
# Thursday     Mathematics
# Friday           History
# dtype: object

# %%
seriesWithRiggedIndex['Monday']
# Out:
# 'Economics'

# %% [markdown]
# ##We can use Pandas '+' to Join the Series
#
# > Both are Concatenated based on Index

# %%
days = pd.Series(['Monday','Tuesday','Wednesday','Thursday','Friday'],index =['Day1','Day2','Day3','Day4','Day5'])
courses= pd.Series(['Economics','Geograghy','Finance','Mathematics','History'],index =['Day1','Day2','Day3','Day4','Day5'])

pdm=days +' '+ courses
pdm
# Out:
# Day1        Monday Economics
# Day2       Tuesday Geograghy
# Day3       Wednesday Finance
# Day4    Thursday Mathematics
# Day5          Friday History
# dtype: object

# %% [markdown]
# ## If both Series don't have common indexes this results in NaN as Value

# %%
days = pd.Series(['Monday','Tuesday','Wednesday','Thursday','Friday'],index =['Day1','Day2','Day3','Day4','Day5'])
courses= pd.Series(['Economics','Finance','Mathematics','History'],index =['Day1','Day2','Day3','Day4'])

pdm=days +' '+ courses
pdm
# Out:
# Day1         Monday Economics
# Day2          Tuesday Finance
# Day3    Wednesday Mathematics
# Day4         Thursday History
# Day5                      NaN
# dtype: object

# %% [markdown]
# #Loc and iLoc usage
#
# >loc gets rows (or columns) with particular labels (name) from the index
#
# >iloc gets rows (or columns) at particular positions in the index and it takes integers
#
# > loc : Location
#
# > iloc : index Location

# %%
sports = {'Football': 'Spain',
          'MBA': 'USA',
          'Cricket': 'India',
          'Athelets': 'Jamaica'}
sports_series = pd.Series(sports) #dictionary key value will become the index of the series
sports_series
# Out:
# Football      Spain
# MBA             USA
# Cricket       India
# Athelets    Jamaica
# dtype: object

# %%
sports_series.loc['Cricket'] #return values where index is Cricket
# Out:
# 'India'

# %%
sports_series.iloc[2] #return value where index is Cricket
# Out:
# 'India'

# %% [markdown]
# #Pandas Dataframe
#
# Two Dimensional Nd-Array

# %%
#np.random.randn(10,5) generate Z-dist random numbers 10x5
my_dataframe = pd.DataFrame(np.random.randn(10,5),columns='column1 column2 column3 column4 column5'.split())

# %%
my_dataframe.head(2)
# Out:
#     column1   column2   column3   column4   column5
# 0  0.005978  0.492293 -0.698707 -1.545939 -0.799724
# 1 -0.518615 -0.293422  0.912220 -1.374400  2.001961

# %%
#We can see the Bahaviour that a Dataframe is combination of Muliple Series
type(my_dataframe['column1'])
# Out:
# pandas.core.series.Series

# %%
type(my_dataframe)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #Reset Index

# %%
my_dataframe['column2'] #selecting a single column
# Out:
# 0   -0.232603
# 1   -0.470163
# 2    0.305154
# 3    0.195623
# 4   -1.412483
# 5   -0.186584
# 6    0.780166
# 7    0.701456
# 8    0.097817
# 9    1.038708
# Name: column2, dtype: float64

# %%
my_dataframe[['column2','column3',"column4"]] #selecting multiple columns.
# Out:
#     column2   column3   column4
# 0 -0.232603  0.455578  0.390559
# 1 -0.470163 -0.592191  0.590486
# 2  0.305154 -0.045565 -0.066079
# 3  0.195623 -2.543881 -0.808131
# 4 -1.412483  0.282267 -0.084493
# 5 -0.186584 -0.090462  1.208261
# 6  0.780166  1.322272 -0.874358
# 7  0.701456  0.543201 -0.481205
# 8  0.097817 -0.269384 -0.468683
# 9  1.038708  0.603780 -1.383646

# %% [markdown]
# ##Adding Column to a DataFrame

# %%
my_dataframe['last']=my_dataframe['column1']*2
my_dataframe
# Out:
#     column1   column2   column3   column4   column5   column6      last
# 0  0.042841 -0.232603  0.455578  0.390559  0.930488  0.085682  0.085682
# 1  0.201065 -0.470163 -0.592191  0.590486 -1.228321  0.402130  0.402130
# 2 -1.141751  0.305154 -0.045565 -0.066079  0.139354 -2.283503 -2.283503
# 3  0.318145  0.195623 -2.543881 -0.808131  1.268318  0.636290  0.636290
# 4  0.913977 -1.412483  0.282267 -0.084493  0.085767  1.827953  1.827953
# 5  0.786752 -0.186584 -0.090462  1.208261  0.005086  1.573504  1.573504
# 6 -2.736597  0.780166  1.322272 -0.874358  1.676092 -5.473194 -5.473194
# 7 -2.119580  0.701456  0.543201 -0.481205  0.165706 -4.239160 -4.239160
# 8  0.760631  0.097817 -0.269384 -0.468683 -0.692130  1.521261  1.521261
# 9 -1.231661  1.038708  0.603780 -1.383646  0.111256 -2.463322 -2.463322

# %%
my_dataframe.drop(['column6','last'],axis=1) #drop multiple columns(axis=1)
# Out:
#     column1   column2   column3   column4   column5
# 0  0.042841 -0.232603  0.455578  0.390559  0.930488
# 1  0.201065 -0.470163 -0.592191  0.590486 -1.228321
# 2 -1.141751  0.305154 -0.045565 -0.066079  0.139354
# 3  0.318145  0.195623 -2.543881 -0.808131  1.268318
# 4  0.913977 -1.412483  0.282267 -0.084493  0.085767
# 5  0.786752 -0.186584 -0.090462  1.208261  0.005086
# 6 -2.736597  0.780166  1.322272 -0.874358  1.676092
# 7 -2.119580  0.701456  0.543201 -0.481205  0.165706
# 8  0.760631  0.097817 -0.269384 -0.468683 -0.692130
# 9 -1.231661  1.038708  0.603780 -1.383646  0.111256

# %%
my_dataframe.drop([0,1],axis=0) #drop multiple rows(axis=0) Remember the Matrix Notation Rows X Columns Rows 0 Columns 1 axis
# Out:
#     column1   column2   column3   column4   column5   column6      last
# 2 -1.141751  0.305154 -0.045565 -0.066079  0.139354 -2.283503 -2.283503
# 3  0.318145  0.195623 -2.543881 -0.808131  1.268318  0.636290  0.636290
# 4  0.913977 -1.412483  0.282267 -0.084493  0.085767  1.827953  1.827953
# 5  0.786752 -0.186584 -0.090462  1.208261  0.005086  1.573504  1.573504
# 6 -2.736597  0.780166  1.322272 -0.874358  1.676092 -5.473194 -5.473194
# 7 -2.119580  0.701456  0.543201 -0.481205  0.165706 -4.239160 -4.239160
# 8  0.760631  0.097817 -0.269384 -0.468683 -0.692130  1.521261  1.521261
# 9 -1.231661  1.038708  0.603780 -1.383646  0.111256 -2.463322 -2.463322

# %% [markdown]
# > The above usage returns the modified DataFrame
#
# > use inplace to modify the DataFrame

# %%
my_dataframe.drop([0,1],axis=0, inplace=True) #drop multiple rows(axis=0) inplace returns None

# %% [markdown]
# #Reset Index

# %%
my_dataframe.index
# Out:
# Int64Index([2, 3, 4, 5, 6, 7, 8, 9], dtype='int64')

# %%
my_dataframe['spin']=['sp1','sp2','sp3','sp4','sp5','sp6','sp7','sp8',]

# %%
my_dataframe.set_index('spin',inplace=True)

# %%
my_dataframe.rename(columns={'column1':'first',
                          'column2':'second',
                          'column3':'third', 
                         'column5':'fourth',
                         'column6':'sixth'},
                 inplace=True) # use rename to rename columns

# %%
my_dataframe.rename(columns={'first':1},inplace=True)

# %%
my_dataframe.head(2)
# Out:
#              1    second     third   column4    fourth     sixth      last
# spin
# sp1  -1.141751  0.305154 -0.045565 -0.066079  0.139354 -2.283503 -2.283503
# sp2   0.318145  0.195623 -2.543881 -0.808131  1.268318  0.636290  0.636290

# %%
my_dataframe.reset_index(inplace=True)

# %% [markdown]
# ##Reading Datasets

# %%
#!cat /content/Automobile.csv
ds=pd.read_csv("/content/drive/MyDrive/ML Experimentation/Automobile.csv")

# %%
ds.head(10)
# Out:
#    symboling  normalized_losses         make  ... city_mpg highway_mpg  price
# 0          3                168  alfa-romero  ...       21          27  13495
# 1          3                168  alfa-romero  ...       21          27  16500
# 2          1                168  alfa-romero  ...       19          26  16500
# 3          2                164         audi  ...       24          30  13950
# 4          2                164         audi  ...       18          22  17450
# 5          2                161         audi  ...       19          25  15250
# 6          1                158         audi  ...       19          25  17710
# 7          1                168         audi  ...       19          25  18920
# 8          1                158         audi  ...       17          20  23875
# 9          2                192          bmw  ...       23          29  16430
#
# [10 rows x 26 columns]

# %%
ds.tail(10)
# Out:
#      symboling  normalized_losses   make  ... city_mpg highway_mpg  price
# 191         -1                 74  volvo  ...       23          28  13415
# 192         -2                103  volvo  ...       24          28  15985
# 193         -1                 74  volvo  ...       24          28  16515
# 194         -2                103  volvo  ...       17          22  18420
# 195         -1                 74  volvo  ...       17          22  18950
# 196         -1                 95  volvo  ...       23          28  16845
# 197         -1                 95  volvo  ...       19          25  19045
# 198         -1                 95  volvo  ...       18          23  21485
# 199         -1                 95  volvo  ...       26          27  22470
# 200         -1                 95  volvo  ...       19          25  22625
#
# [10 rows x 26 columns]

# %%
ds.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
ds.index
# Out:
# RangeIndex(start=0, stop=201, step=1)

# %%
#ds.isnull()
ds.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %% [markdown]
# #Difference between isnull() and isna()
#
# These two DataFrame methods do exactly the same thing! Even their docs are identical. You can even confirm this in pandas' code.
#
# But why have two methods with different names do the same thing? This is because pandas' DataFrames are based on R's DataFrames. In R na and null are two separate things.
#
# However, in python, pandas is built on top of numpy, which has neither na nor null values. Instead numpy has NaN values (which stands for "Not a Number"). Consequently, pandas also uses NaN values.
#
# In short To detect NaN values numpy uses np.isnan().
#
# To detect NaN values pandas uses either .isna() or .isnull(). The NaN values are inherited from the fact that pandas is built on top of numpy, while the two functions' names originate from R's DataFrames, whose structure and functionality pandas tried to mimic.
#
# source: stackexchange: https://bit.ly/3b4YeqY

# %%
ds.dropna() #drop rows with NaN values
ds.describe().T # T for Transpose
# Out:
#                    count          mean  ...       75%       max
# symboling          201.0      0.840796  ...      2.00      3.00
# normalized_losses  201.0    125.189055  ...    150.00    256.00
# wheel_base         201.0     98.797015  ...    102.40    120.90
# length             201.0    174.200995  ...    183.50    208.10
# width              201.0     65.889055  ...     66.60     72.00
# height             201.0     53.766667  ...     55.50     59.80
# curb_weight        201.0   2555.666667  ...   2926.00   4066.00
# engine_size        201.0    126.875622  ...    141.00    326.00
# bore               201.0      3.329701  ...      3.58      3.94
# stroke             201.0      3.261741  ...      3.46      4.17
# compression_ratio  201.0     10.164279  ...      9.40     23.00
# horsepower         201.0    103.263682  ...    116.00    262.00
# peak_rpm           201.0   5121.393035  ...   5500.00   6600.00
# city_mpg           201.0     25.179104  ...     30.00     49.00
# ...

# %%
ds['horsepower'].head(10)
# Out:
# 0    111
# 1    111
# 2    154
# 3    102
# 4    115
# 5    110
# 6    110
# 7    110
# 8    140
# 9    101
# Name: horsepower, dtype: int64

# %%
ds['horsepower'].max()
# Out:
# 262

# %%
ds['horsepower'].min()
# Out:
# 48

# %%
ds[ds['horsepower']>200]['peak_rpm'].mean()
# Out:
# 5675.0

# %%
ds[ds["price"]>20000][['make','price']] #which car is having the price greater than 20,000
# Out:
#               make  price
# 8             audi  23875
# 11             bmw  20970
# 12             bmw  21105
# 13             bmw  24565
# 14             bmw  30760
# 15             bmw  41315
# 16             bmw  36880
# 44          jaguar  32250
# 45          jaguar  35550
# 46          jaguar  36000
# 64   mercedes-benz  25552
# 65   mercedes-benz  28248
# 66   mercedes-benz  28176
# 67   mercedes-benz  31600
# 68   mercedes-benz  34184
# 69   mercedes-benz  35056
# 70   mercedes-benz  40960
# 71   mercedes-benz  45400
# 122        porsche  22018
# 123        porsche  32528
# 124        porsche  34028
# 125        porsche  37028
# 198          volvo  21485
# 199          volvo  22470
# 200          volvo  22625

# %%
ds[(ds['make']=='porsche') & (ds['price']<50000)] #all the volvo cars that are priced less than 50,000
# Out:
#      symboling  normalized_losses     make  ... city_mpg highway_mpg  price
# 122          3                186  porsche  ...       19          27  22018
# 123          3                128  porsche  ...       17          25  32528
# 124          3                128  porsche  ...       17          25  34028
# 125          3                128  porsche  ...       17          25  37028
#
# [4 rows x 26 columns]

# %%
ds[(ds['make']=='porsche') & (ds['price']<50000)][['make','price']]
# Out:
#         make  price
# 122  porsche  22018
# 123  porsche  32528
# 124  porsche  34028
# 125  porsche  37028

# %%
df = pd.DataFrame({'value1':[100,np.nan,234,np.nan],
                   'value2':[300,121,np.nan,np.nan],
                   'value3':['XUI','VYU','NMA','IUY']})
df.head()
# Out:
#    value1  value2 value3
# 0   100.0   300.0    XUI
# 1     NaN   121.0    VYU
# 2   234.0     NaN    NMA
# 3     NaN     NaN    IUY

# %%
df.isnull().sum() #can use isnull or isna
# Out:
# value1    2
# value2    2
# value3    0
# dtype: int64

# %%
df.mean()
# Out:
# value1    167.0
# value2    210.5
# dtype: float64

# %%
df.fillna(df.mean(),inplace=True) #filling the NaN with the mean of each column

# %%
df
# Out:
#    value1  value2 value3
# 0   100.0   300.0    XUI
# 1   167.0   121.0    VYU
# 2   234.0   210.5    NMA
# 3   167.0   210.5    IUY

# %%
df.sort_values(by='value2',ascending=True)
# Out:
#    value1  value2 value3
# 1   167.0   121.0    VYU
# 2   234.0   210.5    NMA
# 3   167.0   210.5    IUY
# 0   100.0   300.0    XUI

# %%
ds.sort_values(by='price',ascending=False).head()
# Out:
#      symboling  normalized_losses           make  ... city_mpg highway_mpg  price
# 71           1                140  mercedes-benz  ...       14          16  45400
# 15           0                149            bmw  ...       16          22  41315
# 70           0                140  mercedes-benz  ...       14          16  40960
# 125          3                128        porsche  ...       17          25  37028
# 16           0                149            bmw  ...       15          20  36880
#
# [5 rows x 26 columns]

# %%
ds['make'].count() #counting how many items are in the number_of_doors columns
# Out:
# 201

# %%
ds['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
df1=pd.DataFrame({'one':[2,3,1,4,5],
     'two':[5,4,3,2,1],
     'letter':['a','a','b','b','c']})

# %%
df2=pd.DataFrame({'one':[2,3,1,4,5],
     'two':[5,4,3,2,1],
     'letter':['a','a','b','b','c']})

# %%
pd.concat([df1,df2],sort=True) #by default it concats on top of each other
# Out:
#   letter  one  two
# 0      a    2    5
# 1      a    3    4
# 2      b    1    3
# 3      b    4    2
# 4      c    5    1
# 0      a    2    5
# 1      a    3    4
# 2      b    1    3
# 3      b    4    2
# 4      c    5    1

# %%
pd.concat([df1,df2],sort=True,axis=1) #use column axis to concat to left
# Out:
#    one  two letter  one  two letter
# 0    2    5      a    2    5      a
# 1    3    4      a    3    4      a
# 2    1    3      b    1    3      b
# 3    4    2      b    4    2      b
# 4    5    1      c    5    1      c

# %% [markdown]
# #Join and Merge
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Inner Join: A intersection B
#
# Left Outer join : A Union (A intersection B)
#
# Right Outer join : B Union (A intersection B)
#
# Full Outer Join : A Union B

# %%
# Dataframe of number of sales made by an employees
sales = {'Jones': 10000,
         'Chris': 5000,
         'Piyush': 440,
         'Meera': 6700,
         'Rahul': 300
        }
# Dataframe of all employees and the region they work in
region = {'Jones': 'West',
          'Chris': np.nan,
          'Piyush': 'West',
          'Meera': np.nan,
          'Anthony': 'East',
          'Ellen': 'South',
          'Josh': 'West',
          'Simran': 'East',
          'Oscar': 'North',}

# %%
salesDf=pd.DataFrame.from_dict(sales,orient='index',columns=['Sales'])
regionDf=pd.DataFrame.from_dict(region,orient='index',columns=['Region'])

# %%
#     it treats the region_df as left table and the sales_df as right 
#     table and therefore all the items in region_df will appear and only 
#     those items in sales_df that matches with region_df will appear

joined_df = regionDf.join(salesDf, how='left')  
print(joined_df)
# Out:
#         Region    Sales
# Jones     West  10000.0
# Chris      NaN   5000.0
# Piyush    West    440.0
# Meera      NaN   6700.0
# Anthony   East      NaN
# Ellen    South      NaN
# Josh      West      NaN
# Simran    East      NaN
# Oscar    North      NaN

# %%
joined_df = regionDf.join(salesDf, how='right')  
print(joined_df)
# Out:
#        Region  Sales
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700
# Rahul     NaN    300

# %%
joined_df = regionDf.join(salesDf, how='outer')  
print(joined_df)
# Out:
#         Region    Sales
# Anthony   East      NaN
# Chris      NaN   5000.0
# Ellen    South      NaN
# Jones     West  10000.0
# Josh      West      NaN
# Meera      NaN   6700.0
# Oscar    North      NaN
# Piyush    West    440.0
# Rahul      NaN    300.0
# Simran    East      NaN

# %%
joined_df = regionDf.join(salesDf, how='inner')  
print(joined_df)
# Out:
#        Region  Sales
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700

# %% [markdown]
# #Merge

# %%
#give title to the index column
regionDf.index.name='names'
salesDf.index.name='names'

# %%
print(pd.merge(regionDf,salesDf,on='names'))
# Out:
#        Region  Sales
# names
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700

# %%
print(pd.merge(regionDf,salesDf,on='names',how='left'))
# Out:
#         Region    Sales
# names
# Jones     West  10000.0
# Chris      NaN   5000.0
# Piyush    West    440.0
# Meera      NaN   6700.0
# Anthony   East      NaN
# Ellen    South      NaN
# Josh      West      NaN
# Simran    East      NaN
# Oscar    North      NaN

# %%
print(pd.merge(regionDf,salesDf,on='names',how='right'))
# Out:
#        Region  Sales
# names
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700
# Rahul     NaN    300

# %%
print(pd.merge(regionDf,salesDf,on='names',how='inner'))
# Out:
#        Region  Sales
# names
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700

# %%
print(pd.merge(regionDf,salesDf,on='names',how='outer'))
# Out:
#         Region    Sales
# names
# Jones     West  10000.0
# Chris      NaN   5000.0
# Piyush    West    440.0
# Meera      NaN   6700.0
# Anthony   East      NaN
# Ellen    South      NaN
# Josh      West      NaN
# Simran    East      NaN
# Oscar    North      NaN
# Rahul      NaN    300.0

# %%
import numpy as np
df=pd.read_csv("./Automobile.csv")
df.head(5)
df.isna().sum()
df.shape
df[df['price']>30000].count()
df[df['horsepower']<100].count()
df['price'].mean()
df['make'].value_counts().head(3)
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64
